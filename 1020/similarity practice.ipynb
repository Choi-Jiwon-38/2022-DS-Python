# %%
# Pandas, Numpy 패키지 import
import numpy as np
import pandas as pd

# %%
# Pandas를 이용하여 metadata 읽어오기
meta = pd.read_csv('movies_metadata.csv')
meta
# Out:
# /var/folders/c8/kdcfy6xj6m5ds2zd66qysr740000gn/T/ipykernel_91659/346243084.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv('movies_metadata.csv')
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  ... release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4      Just when George Banks has recovered from his ...  ...   1995-02-10
# ...                                                  ...  ...          ...
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45461          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464          0.0    87.0                                                 []
# 45465          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45461                       Subdue  False          4.0        1.0
# 45462          Century of Birthing  False          9.0        3.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
# [45466 rows x 24 columns]

# %%
# meta 데이터에서 필요한 column만 추출하기
meta = meta[ ['id', 'original_title', 'original_language', 'genres'] ]
meta
# Out:
#            id               original_title original_language  \
# 0         862                    Toy Story                en
# 1        8844                      Jumanji                en
# 2       15602             Grumpier Old Men                en
# 3       31357            Waiting to Exhale                en
# 4       11862  Father of the Bride Part II                en
# ...       ...                          ...               ...
# 45461  439050                      رگ خواب                fa
# 45462  111109          Siglo ng Pagluluwal                tl
# 45463   67758                     Betrayal                en
# 45464  227506          Satana likuyushchiy                en
# 45465  461257                     Queerama                en
#
#                                                   genres
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
# [45466 rows x 4 columns]

# %%
# 열 이름 변경하기 (rename 사용)
meta = meta.rename(columns = {
    'id': 'movieId',
    'original_title': 'title',
    'original_language': 'language'
})
meta
# Out:
#       movieId                        title language  \
# 0         862                    Toy Story       en
# 1        8844                      Jumanji       en
# 2       15602             Grumpier Old Men       en
# 3       31357            Waiting to Exhale       en
# 4       11862  Father of the Bride Part II       en
# ...       ...                          ...      ...
# 45461  439050                      رگ خواب       fa
# 45462  111109          Siglo ng Pagluluwal       tl
# 45463   67758                     Betrayal       en
# 45464  227506          Satana likuyushchiy       en
# 45465  461257                     Queerama       en
#
#                                                   genres
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
# [45466 rows x 4 columns]

# %%
# language가 'en'인 데이터만 추출하기
meta = meta.loc[meta.language == 'en', :]
meta
# Out:
#       movieId                        title language  \
# 0         862                    Toy Story       en
# 1        8844                      Jumanji       en
# 2       15602             Grumpier Old Men       en
# 3       31357            Waiting to Exhale       en
# 4       11862  Father of the Bride Part II       en
# ...       ...                          ...      ...
# 45459  222848              Caged Heat 3000       en
# 45460   30840                   Robin Hood       en
# 45463   67758                     Betrayal       en
# 45464  227506          Satana likuyushchiy       en
# 45465  461257                     Queerama       en
#
#                                                   genres
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45459           [{'id': 878, 'name': 'Science Fiction'}]
# 45460  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
# [32269 rows x 4 columns]

# %%
# movieId의 타입을 숫자로 변경하기
meta.movieId = pd.to_numeric(meta.movieId)
meta.movieId
# Out:
# /var/folders/c8/kdcfy6xj6m5ds2zd66qysr740000gn/T/ipykernel_91659/275347780.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta.movieId = pd.to_numeric(meta.movieId)
# 0           862
# 1          8844
# 2         15602
# 3         31357
# 4         11862
#           ...
# 45459    222848
# 45460     30840
# 45463     67758
# 45464    227506
# 45465    461257
# Name: movieId, Length: 32269, dtype: int64

# %%
# genre 정제하기 - json string을 python set으로 변환하는 함수를 구현
# [ {'id': ~, 'name': ~ }, {...}, {...} ] 꼴의 json string의 형태를 {장르 1, 장르 2, 장르 3}처러 python set의 형식으로 바꾸기 위함

def str_to_set(x):
    # genre_set = set()
    # for item in eval(x):
    #     genre_set.add(item['name'])
    
    genre_set = { n['name'] for n in eval(x)} # 위 코드와 동일함
    
    return genre_set

# %%
# apply 함수를 이용하여 meta.genres의 모든 값에 str_to_set 적용

meta.genres = meta.genres.apply(str_to_set)
meta.genres
# Out:
# /var/folders/c8/kdcfy6xj6m5ds2zd66qysr740000gn/T/ipykernel_91659/1271191611.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta.genres = meta.genres.apply(str_to_set)
# 0         {Family, Animation, Comedy}
# 1        {Fantasy, Family, Adventure}
# 2                   {Comedy, Romance}
# 3            {Romance, Comedy, Drama}
# 4                            {Comedy}
#                      ...
# 45459               {Science Fiction}
# 45460        {Action, Drama, Romance}
# 45463       {Thriller, Action, Drama}
# 45464                              {}
# 45465                              {}
# Name: genres, Length: 32269, dtype: object

# %%
keywords = pd.read_csv('keywords.csv')
keywords

# keywords의 keywords도 json string의 형태이므로 python set의 형태로 변환
keywords.keywords = keywords.keywords.apply(str_to_set)
keywords
# Out:
#            id                                           keywords
# 0         862  {toy comes to life, toy, friends, friendship, ...
# 1        8844  {disappearance, new home, based on children's ...
# 2       15602  {fishing, best friend, old men, duringcreditss...
# 3       31357  {chick flick, interracial relationship, divorc...
# 4       11862  {pregnancy, midlife crisis, daughter, contrace...
# ...       ...                                                ...
# 46414  439050                                      {tragic love}
# 46415  111109                              {play, artist, pinoy}
# 46416   67758                                                 {}
# 46417  227506                                                 {}
# 46418  461257                                                 {}
#
# [46419 rows x 2 columns]

# %%
# 향후 join을 위하여 keywords의 id를 movieId로 rename
keywords = keywords.rename(columns = {'id': 'movieId'})
keywords
# Out:
#        movieId                                           keywords
# 0          862  {toy comes to life, toy, friends, friendship, ...
# 1         8844  {disappearance, new home, based on children's ...
# 2        15602  {fishing, best friend, old men, duringcreditss...
# 3        31357  {chick flick, interracial relationship, divorc...
# 4        11862  {pregnancy, midlife crisis, daughter, contrace...
# ...        ...                                                ...
# 46414   439050                                      {tragic love}
# 46415   111109                              {play, artist, pinoy}
# 46416    67758                                                 {}
# 46417   227506                                                 {}
# 46418   461257                                                 {}
#
# [46419 rows x 2 columns]

# %%
meta = pd.merge(meta, keywords, on = 'movieId', how = 'inner')
meta
# Out:
#        movieId                        title language  \
# 0          862                    Toy Story       en
# 1         8844                      Jumanji       en
# 2        15602             Grumpier Old Men       en
# 3        31357            Waiting to Exhale       en
# 4        11862  Father of the Bride Part II       en
# ...        ...                          ...      ...
# 32847   222848              Caged Heat 3000       en
# 32848    30840                   Robin Hood       en
# 32849    67758                     Betrayal       en
# 32850   227506          Satana likuyushchiy       en
# 32851   461257                     Queerama       en
#
#                              genres  \
# 0       {Family, Animation, Comedy}
# 1      {Fantasy, Family, Adventure}
# 2                 {Comedy, Romance}
# 3          {Romance, Comedy, Drama}
# 4                          {Comedy}
# ...                             ...
# 32847             {Science Fiction}
# 32848      {Action, Drama, Romance}
# 32849     {Thriller, Action, Drama}
# 32850                            {}
# 32851                            {}
#
#                                                 keywords
# 0      {toy comes to life, toy, friends, friendship, ...
# 1      {disappearance, new home, based on children's ...
# 2      {fishing, best friend, old men, duringcreditss...
# 3      {chick flick, interracial relationship, divorc...
# 4      {pregnancy, midlife crisis, daughter, contrace...
# ...                                                  ...
# 32847                                                 {}
# 32848                                                 {}
# 32849                                                 {}
# 32850                                                 {}
# 32851                                                 {}
#
# [32852 rows x 5 columns]

# %%
# Jaccard 유사도를 구하는 함수
def jaccard(a, b):
    if len(a | b) == 0:
        return 0
    return len(a & b) / len(a | b)

# %%
dk = meta.loc[meta.title == 'The Dark Knight'].iloc[0]
dkr = meta.loc[meta.title == 'The Dark Knight Rises'].iloc[0]

# 두 개를 묶어서 테이블로 변환하는 방법
pd.concat([dk, dkr], axis = 1).T
# Out:
#       movieId                  title language  \
# 10278     155        The Dark Knight       en
# 14315   49026  The Dark Knight Rises       en
#
#                                  genres  \
# 10278  {Thriller, Action, Drama, Crime}
# 14315  {Thriller, Action, Drama, Crime}
#
#                                                 keywords
# 10278  {chaos, vigilante, joker, scarecrow, gotham ci...
# 14315  {vigilante, terrorist, destruction, gotham cit...

# %%
dk_gk = dk.genres | dk.keywords # dk의 장르와 키워드를 합집합으로 만듦
dkr_gk = dkr.genres | dkr.keywords # dkr의 장르와 키워드를 합집합으로 만듦

jaccard(dk_gk, dkr_gk)
# Out:
# 0.37142857142857144

# %%
ratings = pd.read_csv('ratings_small.csv')
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1       31     2.5  1260759144
# 1            1     1029     3.0  1260759179
# 2            1     1061     3.0  1260759182
# 3            1     1129     2.0  1260759185
# 4            1     1172     4.0  1260759205
# ...        ...      ...     ...         ...
# 99999      671     6268     2.5  1065579370
# 100000     671     6269     4.0  1065149201
# 100001     671     6365     4.0  1070940363
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724
#
# [100004 rows x 4 columns]

# %%
ratings =pd.merge(ratings, meta[['movieId', 'title']], on = 'movieId', how = 'inner')
ratings = ratings[ ['userId', 'movieId', 'rating', 'title'] ]
ratings
# Out:
#        userId  movieId  rating              title
# 0           1     1371     2.5          Rocky III
# 1           4     1371     4.0          Rocky III
# 2           7     1371     3.0          Rocky III
# 3          19     1371     4.0          Rocky III
# 4          21     1371     3.0          Rocky III
# ...       ...      ...     ...                ...
# 33295     652   127728     5.0               8:46
# 33296     652   129009     4.0     Love Is a Ball
# 33297     653     2103     3.0            Solaris
# 33298     659      167     4.0              K-PAX
# 33299     659      563     3.0  Starship Troopers
#
# [33300 rows x 4 columns]

# %%
matrix = ratings.pivot_table(index = 'userId', columns = 'title', values = 'rating')

# %%
dk = matrix['The Dark Knight']
pn = matrix['Prom Night']

# %%
def pearson(a, b):
    a = a - a.mean()
    b = b - b.mean()

    denom = (np.sum(a ** 2) * np.sum(b ** 2)) ** 0.5 # 분모

    if denom == 0:
        return 0
    else:
        return np.sum(a * b) / denom

# %%
pearson(dk, pn)
# Out:
# 0.773565934694095
